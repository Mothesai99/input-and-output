# %%
x=45.23
hex(id(x))
# Out:
# '0x1e5f57c6530'

# %%
firstVarName='saikrishna'
print(firstVarName)
# Out:
# saikrishna

# %%
FirstVariance='sai'
print(FirstVariance)
# Out:
# sai

# %%
first_var_name='sai'
print(first_var_name)
# Out:
# sai

# %%
a,b,c=10,20,30
print(a,b,c)
# Out:
# 10 20 30

# %%
a=b=c=d=5
print(a,b,c,d)
# Out:
# 5 5 5 5

# %%
a,b,c=1,4.5,"hello"
print(a)
print(b)
print(c)
# Out:
# 1
# 4.5
# hello

# %% [markdown]
# # python guidenlines

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# # ####input

# %% [markdown]
# # ####input

# %% [markdown]
# # input

# %%
name=input('enter the name')
print(name)
# Out:
# enter the namesai
# sai

# %%
x=int(input('enter number'))
sq=x*x
print(sq)
# Out:
# enter number5
# 25

# %%
num1=int(input('enter num'))
num2=int(input('enter num'))
sum=num1+num2
print(sum)
# Out:
# enter num5
# enter num5
# 10

# %%
num1=int(input("enter num"))
num=int(input("enter num"))
mul=num1*num2
print(mul)
# Out:
# enter num5
# enter num5
# 25

# %%
num1=int(input("enter num"))
num2=int(input("enter num"))
sub=num1-num2
print(sub)
# Out:
# enter num45
# enter num12
# 33

# %%
num1=int(input("enter num"))
num2=int(input("enter num"))
div=num1/num2
print(div)
# Out:
# enter num25
# enter num5
# 5.0

# %%
num1=int(input("enter num"))
num2=int(input("enter num"))
num3=int(input("enter num"))
num4=int(input("enter num"))
num5=int(input("enter num"))
aver=num1+num2+num3+num4+num5/5
print(aver)
# Out:
# enter num4
# enter num5
# enter num5
# enter num5
# enter num4
# 19.8

# %%
p=int(input("enter num"))
r=int(input("enter num"))
t=int(input("enter num"))
SI=p*t*r/100
print(SI)
# Out:
# enter num1
# enter num7
# enter num8
# 0.56

# %%
l=int(input("enter num"))
b=int(input("enter num"))
rec=2*(l+b)
print(rec)
# Out:
# enter num12
# enter num153
# 330

# %%
a=10
b=23
c=a+b
print("addition",c)
# Out:
# addition 33

# %%
side=int(input("enter the side of operator"))
area=side*side
print("area of the square",area)
# Out:
# enter the side of operator4
# area of the square 16

# %%
a=100
b=23
c=a/b
print("division",c)
# Out:
# division 4.3478260869565215

# %%
a=100
b=23
c=a//b
print("floor division",c)
# Out:
# floor division 4

# %%
a=5
b=3
c=a/b
print("remainder",c)
# Out:
# remainder 1.6666666666666667

# %%
a=10
b=5
c=a % b
print("remainder",c)
# Out:
# remainder 0

# %%
a=2
b=3
c=a**b
print("power",c)
# Out:
# power 8

# %%
a="shiv"
b="verma"
print(a+b)
print(a+" "+b)
print(a,b)
# Out:
# shivverma
# shiv verma
# shiv verma

# %%
num1=int(input("enter the value"))
num2=int(input("enter the value"))
modulus= num1 %num2
print(modulus)
# Out:
# enter the value12
# enter the value12
# 0

# %%
x=int(input("enter the value"))
y=int(input("enter the value"))
temp=x
x=y
y=temp
print(x,y)
# Out:
# enter the value1
# enter the value23
# 23 1

# %%
x=int(input("enter the value"))
y=int(input("enter the value"))
x=x*y
y=x//y
x=x//y
print(x,y)
# Out:
# enter the value2
# enter the value11
# 11 2

# %%
x=int(input("enter the value"))
y=int(input("enter the value"))
x=x+y
y=x-y
x=x-y
print(x,y)
# Out:
# enter the value14
# enter the value41
# 41 14

# %%
bs=int(input('enter value'))
hra=bs*0.1
das=bs*0.05
net=bs+das+hra
print(net)
# Out:
# enter value1
# 1.1500000000000001

# %%
side=4
perimeter=4*side
print("perimeter of square",perimeter)
# Out:
# perimeter of square 16

# %%
distance=4
circle=(1/2*distance)
print("perimeter of circle",circle)
# Out:
# perimeter of circle 2.0

# %%
x=10
y=20
print("is x is greater than y",x>y)
print("is y is greater than x",x<y)
print("is x is equal to y",x==y)
print("is x is greater than equal to y",x>=y)
print("is y is greater than or equal to x",x<=y)
# Out:
# is x is greater than y False
# is y is greater than x True
# is x is equal to y False
# is x is greater than equal to y False
# is y is greater than or equal to x True

# %%
x=int(input("enter a value"))
y=int(input("enter a value"))
print("is x is greater than y",x>y)
print("is y is greater than x",x<y)
print("is x is equal to y",x==y)
print("is x is greater than equal to y",x>=y)
print("is y is greater than or equal to x",x<=y)
# Out:
# enter a value12
# enter a value12
# is x is greater than y False
# is y is greater than x False
# is x is equal to y True
# is x is greater than equal to y True
# is y is greater than or equal to x True

# %%
a='shiv'
b='verma'
c='shiv'
print(a==b)
print(a==c)
print(a!=b)
# Out:
# False
# True
# True

# %%
x=True
y=False
print(x and y)
print(x or y)
print(not x)
# Out:
# False
# True
# False

# %%
a=10
b=12
print(a>10 and a<b)
# Out:
# False

# %%
a=10
b=12
print(a>10 or a<b)
# Out:
# True

# %%
a=10
b=12
print(a>10 or a>b)
# Out:
# False

# %%
a=int(input("enter a  first value"))
b=int(input("enter a  secound value"))
if a==b:
    print("both are equal")
# Out:
# enter a  first value2
# enter a  secound value2
# both are equal

# %%
a=int(input("enter a  first value"))
b=int(input("enter a  secound value"))
if a==b:
    print("both are equal")
    else:
        print("both are not equal")
# Out:
#   Input In [42]
#     else:
#     ^
# SyntaxError: invalid syntax

# %%
a=int(input("enter the marks"))
if a>20:
    print("student is pass")
else:
        print("student is fail")
# Out:
# enter the marks25
# student is pass

# %%
a=int(input("enter the age"))
if a>18:
    print("egilble for vote")
else:
        print("egilble for not vote")
# Out:
# enter the age20
# egilble for vote

# %%
a=int(input("enter the age"))
if a>18:
    print("egilble for vote")
else:
        print("egilble for not vote")
# Out:
# enter the age17
# egilble for not vote

# %%
a=int(input("enter the first num"))
b=int(input("enter the secound num"))
if a>b:
    print("greater")
else:
        print("lesser")
# Out:
# enter the first num45
# enter the secound num25
# greater

# %%
x=7
x*=3
print(x)
# Out:
# 21

# %%
x=5
y=x+3
y=int(str(y)+"2")
print(y)
# Out:
# 82

# %%
d=7425
speed=550
time=d/speed
print(time)
# Out:
# 13.5

# %%
x=100
print(x)
x+=20
print(x)
x-=20
print(x)
x*=20
print(x)
x/=20
print(x)
x//=20
print(x)
x**=20
print(x)
# Out:
# 100
# 120
# 100
# 2000
# 100.0
# 5.0
# 95367431640625.0

# %%
m="my name saikrishna"
print('is' in m)
# Out:
# True

# %%
m="my name saikrishna"
print('is' not in m)
# Out:
# False

# %%
m="my name saikrishna"
print('it' not in m)
# Out:
# True

# %%
x=6
y=4
print("bitwise AND",x&y)
# Out:
# bitwise AND 4

# %%
x=6
y=4
print("bitwise or",x|y)
# Out:
# bitwise or 6

# %%
num=7
if num>3:
print(3)
if num<5:
    print("5")
    if num==7:
        print("7")
# Out:
#   Input In [62]
#     print(3)
#     ^
# IndentationError: expected an indented block

# %%
temp=int(input())
if temp>100:
    print("boiling")
# Out:
# 105
# boiling

# %%
input=50
print(50*20/100)
print(74.5*74.5/100)
# Out:
# 10.0
# 55.5025

# %%
a="hello,world"
print(a.lower())
# Out:
# hello,world

# %%
a="hello,world"
print(a.upper())
# Out:
# HELLO,WORLD
